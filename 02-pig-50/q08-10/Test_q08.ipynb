# %%
########################################################################################################
## Ejecución de Pig en Jupyter
##    A continuación se describe como ejecutar comandos de Pig en Jupyter usando la extensión de Jupyter bigdata.
# %load_ext bigdata
# %pig_start
# %timeout 300
## WordCount en Apache Pig
##   Se cargan los archivos en Apache Pig.
# !hadoop fs -put *.tsv .
# !hadoop fs -ls
# Out:
# Found 2 items
# -rw-r--r--   1 root supergroup        632 2020-03-04 05:08 data.csv
# -rw-r--r--   1 root supergroup       1780 2020-03-04 05:37 data.tsv

# %%
# %%pig
# lines = LOAD 'data.tsv' AS (clave:CHARARRAY, reg1:BAG{t:(p:CHARARRAY)}, reg2:MAP[]);
# DUMP lines;
# Out:
# eg2:MAP[]);AD 'data.tsv' AS (clave:CHARARRAY, reg1:BAG{t:(p:CHARARRAY)}, r
#  DUMP lines;
# 2020-03-04 05:37:44,016 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:37:44,184 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# 2020-03-04 05:37:44,188 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.output.compress is deprecated. Instead, use mapreduce.output.fileoutputformat.compress
# 2020-03-04 05:37:44,199 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.submit.replication is deprecated. Instead, use mapreduce.client.submit.file.replication
# 2020-03-04 05:37:45,046 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker.http.address is deprecated. Instead, use mapreduce.jobtracker.http.address
# 2020-03-04 05:37:45,058 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:37:45,078 [JobControl] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2020-03-04 05:37:45,158 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-04 05:37:45,183 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 05:37:45,254 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-03-04 05:37:45,386 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583298438667_0041
# 2020-03-04 05:37:45,508 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-04 05:37:45,611 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583298438667_0041
# 2020-03-04 05:37:45,643 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://379139e472df:8088/proxy/application_1583298438667_0041/
# 2020-03-04 05:38:00,810 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:00,818 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:38:00,967 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:00,973 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:38:01,003 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 2020-03-04 05:38:01,005 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:01,011 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:38:01,078 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:01,085 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:38:01,131 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:01,135 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:38:01,167 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:01,176 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:38:01,238 [main] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# (E,{(b),(g),(f)},[hhh#2,bbb#0,jjj#3,ddd#9,ggg#8])
# (A,{(a),(f),(c)},[aaa#3,hhh#9,ccc#2,ddd#0])
# (B,{(f),(e),(a),(c)},[ccc#6,jjj#1,ddd#2,ggg#5])
# (A,{(a),(b)},[iii#5,hhh#9,bbb#1,eee#7])
# (C,{(f),(g),(d),(a)},[iii#6,jjj#3,eee#4,ddd#5])
# (A,{(c),(d)},[aaa#7,hhh#0,ccc#4,bbb#2,fff#1])
# (A,{(g),(d),(a)},[aaa#5,iii#0,ccc#1,jjj#7,ddd#2,fff#8])
# (B,{(b),(a)},[ddd#2,hhh#1,fff#3])
# (E,{(d),(e),(a),(f)},[iii#9,ccc#5,bbb#0,eee#4,ggg#6,fff#7])
# (B,{(d),(b),(g),(f)},[iii#4,bbb#7,jjj#9,eee#3,ggg#2,fff#5])
# (C,{(d),(c),(f),(b)},[iii#0,hhh#6,jjj#1,eee#4,fff#2])
# (C,{(d),(e),(a),(c)},[iii#6,ggg#9,bbb#7])
# (D,{(g),(e),(f),(b)},[aaa#3,ccc#6,bbb#9,eee#2,fff#4])
# (E,{(c),(f)},[aaa#8,ddd#5,jjj#1])
# (B,{(d),(b)},[aaa#2,ccc#0,jjj#6,ddd#3,fff#7])
# (D,{(f),(e)},[ccc#0,bbb#9,eee#6,ddd#3])
# (E,{(e),(b),(f)},[iii#3,hhh#5,bbb#6,ddd#2,ggg#9,fff#4])
# (D,{(g),(a)},[hhh#4,ccc#9,jjj#5])
# (E,{(e),(c),(f),(a)},[iii#6,ccc#1,fff#9])
# (E,{(e),(a)},[aaa#3,bbb#9,fff#1])
# (E,{(e),(f)},[aaa#4,iii#2,ddd#9])
# (E,{(c),(b),(g)},[iii#7,ccc#5,fff#8])
# (D,{(c),(f),(a)},[eee#3,ddd#7,jjj#2])
# (A,{(f),(a),(d)},[ccc#7,bbb#3,jjj#1,ddd#9,ggg#0])
# (E,{(c),(d)},[aaa#1,iii#7,hhh#9,ccc#0,jjj#6,ggg#8])
# (E,{(e),(d),(c)},[iii#4,ccc#1,bbb#7,eee#6,ddd#0,fff#3])
# (A,{(a),(e),(f)},[ddd#5,ccc#4,fff#0])
# (E,{(c),(a),(g)},[hhh#3,ccc#0,jjj#7,ddd#9,ggg#6])
# (A,{(f),(e)},[iii#7,hhh#6,ccc#3,jjj#0,eee#5])
# (C,{(f),(c),(a),(g)},[aaa#2,ccc#7,eee#1,ddd#6,ggg#0,fff#4])
# (A,{(b),(f)},[aaa#9,ccc#6,bbb#3,eee#5,ddd#0])
# (D,{(b),(f)},[aaa#6,iii#4,hhh#1,bbb#7,ddd#5,fff#9])
# (E,{(a),(c)},[ccc#1,eee#5,ggg#2,fff#3])
# (B,{(b),(f),(c)},[iii#7,hhh#5,ccc#1,jjj#8,ddd#0,ggg#3])
# (B,{(f),(a),(e)},[hhh#6,ccc#3,bbb#8,jjj#0,ddd#7])
# (D,{(a),(f)},[aaa#0,ddd#3,fff#5])
# (B,{(c),(a)},[iii#7,ccc#0,bbb#4,jjj#2,ddd#5])
# (C,{(c),(a),(e),(f)},[eee#0,hhh#6,fff#2])
# (E,{(e),(d)},[eee#0,iii#2,fff#9])
# (E,{(f),(a),(d)},[hhh#8,ggg#3,jjj#5])

# %%
# %%pig
# -- genera una tabla llamada words con una palabra por registro
# words = FOREACH lines GENERATE FLATTEN(reg1) AS (p:CHARARRAY), FLATTEN(reg2) AS (q:CHARARRAY, r:INT);
# DUMP words;
# Out:
#  -- genera una tabla llamada words con una palabra por registro
# g2) AS (q:CHARARRAY, r:INT);ATE FLATTEN(reg1) AS (p:CHARARRAY), FLATTEN(re
#  DUMP words;
# 2020-03-04 05:38:11,769 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:11,916 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:11,940 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-04 05:38:11,959 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 05:38:12,001 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-03-04 05:38:12,039 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583298438667_0042
# 2020-03-04 05:38:12,042 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-04 05:38:12,077 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583298438667_0042
# 2020-03-04 05:38:12,082 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://379139e472df:8088/proxy/application_1583298438667_0042/
# 2020-03-04 05:38:27,275 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:27,279 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:38:27,844 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:27,847 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:38:27,876 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:27,880 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:38:27,913 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:27,916 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:38:27,947 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:27,951 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:38:27,975 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:27,979 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:38:28,023 [main] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# (b,bbb,0)
# (b,ddd,9)
# (b,ggg,8)
# (b,hhh,2)
# (b,jjj,3)
# (g,bbb,0)
# (g,ddd,9)
# (g,ggg,8)
# (g,hhh,2)
# (g,jjj,3)
# (f,bbb,0)
# (f,ddd,9)
# (f,ggg,8)
# (f,hhh,2)
# (f,jjj,3)
# (a,aaa,3)
# (a,ccc,2)
# (a,ddd,0)
# (a,hhh,9)
# (f,aaa,3)
# (f,ccc,2)
# (f,ddd,0)
# (f,hhh,9)
# (c,aaa,3)
# (c,ccc,2)
# (c,ddd,0)
# (c,hhh,9)
# (f,ccc,6)
# (f,ddd,2)
# (f,ggg,5)
# (f,jjj,1)
# (e,ccc,6)
# (e,ddd,2)
# (e,ggg,5)
# (e,jjj,1)
# (a,ccc,6)
# (a,ddd,2)
# (a,ggg,5)
# (a,jjj,1)
# (c,ccc,6)
# (c,ddd,2)
# (c,ggg,5)
# (c,jjj,1)
# (a,bbb,1)
# (a,eee,7)
# (a,iii,5)
# (a,hhh,9)
# (b,bbb,1)
# (b,eee,7)
# (b,iii,5)
# (b,hhh,9)
# (f,eee,4)
# (f,ddd,5)
# (f,iii,6)
# (f,jjj,3)
# (g,eee,4)
# (g,ddd,5)
# (g,iii,6)
# (g,jjj,3)
# (d,eee,4)
# (d,ddd,5)
# (d,iii,6)
# (d,jjj,3)
# (a,eee,4)
# (a,ddd,5)
# (a,iii,6)
# (a,jjj,3)
# (c,aaa,7)
# (c,ccc,4)
# (c,bbb,2)
# (c,fff,1)
# (c,hhh,0)
# (d,aaa,7)
# (d,ccc,4)
# (d,bbb,2)
# (d,fff,1)
# (d,hhh,0)
# (g,aaa,5)
# (g,ccc,1)
# (g,ddd,2)
# (g,fff,8)
# (g,iii,0)
# (g,jjj,7)
# (d,aaa,5)
# (d,ccc,1)
# (d,ddd,2)
# (d,fff,8)
# (d,iii,0)
# (d,jjj,7)
# (a,aaa,5)
# (a,ccc,1)
# (a,ddd,2)
# (a,fff,8)
# (a,iii,0)
# (a,jjj,7)
# (b,ddd,2)
# (b,fff,3)
# (b,hhh,1)
# (a,ddd,2)
# (a,fff,3)
# (a,hhh,1)
# (d,ccc,5)
# (d,bbb,0)
# (d,eee,4)
# (d,ggg,6)
# (d,fff,7)
# (d,iii,9)
# (e,ccc,5)
# (e,bbb,0)
# (e,eee,4)
# (e,ggg,6)
# (e,fff,7)
# (e,iii,9)
# (a,ccc,5)
# (a,bbb,0)
# (a,eee,4)
# (a,ggg,6)
# (a,fff,7)
# (a,iii,9)
# (f,ccc,5)
# (f,bbb,0)
# (f,eee,4)
# (f,ggg,6)
# (f,fff,7)
# (f,iii,9)
# (d,bbb,7)
# (d,eee,3)
# (d,ggg,2)
# (d,fff,5)
# (d,iii,4)
# (d,jjj,9)
# (b,bbb,7)
# (b,eee,3)
# (b,ggg,2)
# (b,fff,5)
# (b,iii,4)
# (b,jjj,9)
# (g,bbb,7)
# (g,eee,3)
# (g,ggg,2)
# (g,fff,5)
# (g,iii,4)
# (g,jjj,9)
# (f,bbb,7)
# (f,eee,3)
# (f,ggg,2)
# (f,fff,5)
# (f,iii,4)
# (f,jjj,9)
# (d,eee,4)
# (d,fff,2)
# (d,iii,0)
# (d,hhh,6)
# (d,jjj,1)
# (c,eee,4)
# (c,fff,2)
# (c,iii,0)
# (c,hhh,6)
# (c,jjj,1)
# (f,eee,4)
# (f,fff,2)
# (f,iii,0)
# (f,hhh,6)
# (f,jjj,1)
# (b,eee,4)
# (b,fff,2)
# (b,iii,0)
# (b,hhh,6)
# (b,jjj,1)
# (d,bbb,7)
# (d,ggg,9)
# (d,iii,6)
# (e,bbb,7)
# (e,ggg,9)
# (e,iii,6)
# (a,bbb,7)
# (a,ggg,9)
# (a,iii,6)
# (c,bbb,7)
# (c,ggg,9)
# (c,iii,6)
# (g,aaa,3)
# (g,ccc,6)
# (g,bbb,9)
# (g,eee,2)
# (g,fff,4)
# (e,aaa,3)
# (e,ccc,6)
# (e,bbb,9)
# (e,eee,2)
# (e,fff,4)
# (f,aaa,3)
# (f,ccc,6)
# (f,bbb,9)
# (f,eee,2)
# (f,fff,4)
# (b,aaa,3)
# (b,ccc,6)
# (b,bbb,9)
# (b,eee,2)
# (b,fff,4)
# (c,aaa,8)
# (c,ddd,5)
# (c,jjj,1)
# (f,aaa,8)
# (f,ddd,5)
# (f,jjj,1)
# (d,aaa,2)
# (d,ccc,0)
# (d,ddd,3)
# (d,fff,7)
# (d,jjj,6)
# (b,aaa,2)
# (b,ccc,0)
# (b,ddd,3)
# (b,fff,7)
# (b,jjj,6)
# (f,ccc,0)
# (f,bbb,9)
# (f,eee,6)
# (f,ddd,3)
# (e,ccc,0)
# (e,bbb,9)
# (e,eee,6)
# (e,ddd,3)
# (e,bbb,6)
# (e,ddd,2)
# (e,ggg,9)
# (e,fff,4)
# (e,iii,3)
# (e,hhh,5)
# (b,bbb,6)
# (b,ddd,2)
# (b,ggg,9)
# (b,fff,4)
# (b,iii,3)
# (b,hhh,5)
# (f,bbb,6)
# (f,ddd,2)
# (f,ggg,9)
# (f,fff,4)
# (f,iii,3)
# (f,hhh,5)
# (g,ccc,9)
# (g,hhh,4)
# (g,jjj,5)
# (a,ccc,9)
# (a,hhh,4)
# (a,jjj,5)
# (e,ccc,1)
# (e,fff,9)
# (e,iii,6)
# (c,ccc,1)
# (c,fff,9)
# (c,iii,6)
# (f,ccc,1)
# (f,fff,9)
# (f,iii,6)
# (a,ccc,1)
# (a,fff,9)
# (a,iii,6)
# (e,aaa,3)
# (e,bbb,9)
# (e,fff,1)
# (a,aaa,3)
# (a,bbb,9)
# (a,fff,1)
# (e,aaa,4)
# (e,ddd,9)
# (e,iii,2)
# (f,aaa,4)
# (f,ddd,9)
# (f,iii,2)
# (c,ccc,5)
# (c,fff,8)
# (c,iii,7)
# (b,ccc,5)
# (b,fff,8)
# (b,iii,7)
# (g,ccc,5)
# (g,fff,8)
# (g,iii,7)
# (c,eee,3)
# (c,ddd,7)
# (c,jjj,2)
# (f,eee,3)
# (f,ddd,7)
# (f,jjj,2)
# (a,eee,3)
# (a,ddd,7)
# (a,jjj,2)
# (f,ccc,7)
# (f,bbb,3)
# (f,ddd,9)
# (f,ggg,0)
# (f,jjj,1)
# (a,ccc,7)
# (a,bbb,3)
# (a,ddd,9)
# (a,ggg,0)
# (a,jjj,1)
# (d,ccc,7)
# (d,bbb,3)
# (d,ddd,9)
# (d,ggg,0)
# (d,jjj,1)
# (c,aaa,1)
# (c,ccc,0)
# (c,ggg,8)
# (c,iii,7)
# (c,hhh,9)
# (c,jjj,6)
# (d,aaa,1)
# (d,ccc,0)
# (d,ggg,8)
# (d,iii,7)
# (d,hhh,9)
# (d,jjj,6)
# (e,ccc,1)
# (e,bbb,7)
# (e,eee,6)
# (e,ddd,0)
# (e,fff,3)
# (e,iii,4)
# (d,ccc,1)
# (d,bbb,7)
# (d,eee,6)
# (d,ddd,0)
# (d,fff,3)
# (d,iii,4)
# (c,ccc,1)
# (c,bbb,7)
# (c,eee,6)
# (c,ddd,0)
# (c,fff,3)
# (c,iii,4)
# (a,ccc,4)
# (a,ddd,5)
# (a,fff,0)
# (e,ccc,4)
# (e,ddd,5)
# (e,fff,0)
# (f,ccc,4)
# (f,ddd,5)
# (f,fff,0)
# (c,ccc,0)
# (c,ddd,9)
# (c,ggg,6)
# (c,hhh,3)
# (c,jjj,7)
# (a,ccc,0)
# (a,ddd,9)
# (a,ggg,6)
# (a,hhh,3)
# (a,jjj,7)
# (g,ccc,0)
# (g,ddd,9)
# (g,ggg,6)
# (g,hhh,3)
# (g,jjj,7)
# (f,ccc,3)
# (f,eee,5)
# (f,iii,7)
# (f,hhh,6)
# (f,jjj,0)
# (e,ccc,3)
# (e,eee,5)
# (e,iii,7)
# (e,hhh,6)
# (e,jjj,0)
# (f,aaa,2)
# (f,ccc,7)
# (f,eee,1)
# (f,ddd,6)
# (f,ggg,0)
# (f,fff,4)
# (c,aaa,2)
# (c,ccc,7)
# (c,eee,1)
# (c,ddd,6)
# (c,ggg,0)
# (c,fff,4)
# (a,aaa,2)
# (a,ccc,7)
# (a,eee,1)
# (a,ddd,6)
# (a,ggg,0)
# (a,fff,4)
# (g,aaa,2)
# (g,ccc,7)
# (g,eee,1)
# (g,ddd,6)
# (g,ggg,0)
# (g,fff,4)
# (b,aaa,9)
# (b,ccc,6)
# (b,bbb,3)
# (b,eee,5)
# (b,ddd,0)
# (f,aaa,9)
# (f,ccc,6)
# (f,bbb,3)
# (f,eee,5)
# (f,ddd,0)
# (b,aaa,6)
# (b,bbb,7)
# (b,ddd,5)
# (b,fff,9)
# (b,iii,4)
# (b,hhh,1)
# (f,aaa,6)
# (f,bbb,7)
# (f,ddd,5)
# (f,fff,9)
# (f,iii,4)
# (f,hhh,1)
# (a,ccc,1)
# (a,eee,5)
# (a,ggg,2)
# (a,fff,3)
# (c,ccc,1)
# (c,eee,5)
# (c,ggg,2)
# (c,fff,3)
# (b,ccc,1)
# (b,ddd,0)
# (b,ggg,3)
# (b,iii,7)
# (b,hhh,5)
# (b,jjj,8)
# (f,ccc,1)
# (f,ddd,0)
# (f,ggg,3)
# (f,iii,7)
# (f,hhh,5)
# (f,jjj,8)
# (c,ccc,1)
# (c,ddd,0)
# (c,ggg,3)
# (c,iii,7)
# (c,hhh,5)
# (c,jjj,8)
# (f,ccc,3)
# (f,bbb,8)
# (f,ddd,7)
# (f,hhh,6)
# (f,jjj,0)
# (a,ccc,3)
# (a,bbb,8)
# (a,ddd,7)
# (a,hhh,6)
# (a,jjj,0)
# (e,ccc,3)
# (e,bbb,8)
# (e,ddd,7)
# (e,hhh,6)
# (e,jjj,0)
# (a,aaa,0)
# (a,ddd,3)
# (a,fff,5)
# (f,aaa,0)
# (f,ddd,3)
# (f,fff,5)
# (c,ccc,0)
# (c,bbb,4)
# (c,ddd,5)
# (c,iii,7)
# (c,jjj,2)
# (a,ccc,0)
# (a,bbb,4)
# (a,ddd,5)
# (a,iii,7)
# (a,jjj,2)
# (c,eee,0)
# (c,fff,2)
# (c,hhh,6)
# (a,eee,0)
# (a,fff,2)
# (a,hhh,6)
# (e,eee,0)
# (e,fff,2)
# (e,hhh,6)
# (f,eee,0)
# (f,fff,2)
# (f,hhh,6)
# (e,eee,0)
# (e,fff,9)
# (e,iii,2)
# (d,eee,0)
# (d,fff,9)
# (d,iii,2)
# (f,ggg,3)
# (f,hhh,8)
# (f,jjj,5)
# (a,ggg,3)
# (a,hhh,8)
# (a,jjj,5)
# (d,ggg,3)
# (d,hhh,8)
# (d,jjj,5)

# %%
# %%pig
# --
# -- Los campos de la tupla pueden ser accesados
# -- por nombre o por posición.
# --
# tup = FOREACH words GENERATE p,q;
# DUMP tup;
# Out:
#  --
#  -- Los campos de la tupla pueden ser accesados
#  -- por nombre o por posici??n.
#  --
#  tup = FOREACH words GENERATE p,q;
#  DUMP tup;
# 2020-03-04 05:38:28,487 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:29,426 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:29,449 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-04 05:38:29,469 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 05:38:29,902 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-03-04 05:38:29,935 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583298438667_0043
# 2020-03-04 05:38:29,938 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-04 05:38:29,974 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583298438667_0043
# 2020-03-04 05:38:29,980 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://379139e472df:8088/proxy/application_1583298438667_0043/
# 2020-03-04 05:38:45,249 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:45,255 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:38:45,320 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:45,323 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:38:45,354 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:45,357 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:38:45,409 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:45,413 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:38:45,444 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:45,448 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:38:45,480 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:45,484 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:38:45,520 [main] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# (b,bbb)
# (b,ddd)
# (b,ggg)
# (b,hhh)
# (b,jjj)
# (g,bbb)
# (g,ddd)
# (g,ggg)
# (g,hhh)
# (g,jjj)
# (f,bbb)
# (f,ddd)
# (f,ggg)
# (f,hhh)
# (f,jjj)
# (a,aaa)
# (a,ccc)
# (a,ddd)
# (a,hhh)
# (f,aaa)
# (f,ccc)
# (f,ddd)
# (f,hhh)
# (c,aaa)
# (c,ccc)
# (c,ddd)
# (c,hhh)
# (f,ccc)
# (f,ddd)
# (f,ggg)
# (f,jjj)
# (e,ccc)
# (e,ddd)
# (e,ggg)
# (e,jjj)
# (a,ccc)
# (a,ddd)
# (a,ggg)
# (a,jjj)
# (c,ccc)
# (c,ddd)
# (c,ggg)
# (c,jjj)
# (a,bbb)
# (a,eee)
# (a,iii)
# (a,hhh)
# (b,bbb)
# (b,eee)
# (b,iii)
# (b,hhh)
# (f,eee)
# (f,ddd)
# (f,iii)
# (f,jjj)
# (g,eee)
# (g,ddd)
# (g,iii)
# (g,jjj)
# (d,eee)
# (d,ddd)
# (d,iii)
# (d,jjj)
# (a,eee)
# (a,ddd)
# (a,iii)
# (a,jjj)
# (c,aaa)
# (c,ccc)
# (c,bbb)
# (c,fff)
# (c,hhh)
# (d,aaa)
# (d,ccc)
# (d,bbb)
# (d,fff)
# (d,hhh)
# (g,aaa)
# (g,ccc)
# (g,ddd)
# (g,fff)
# (g,iii)
# (g,jjj)
# (d,aaa)
# (d,ccc)
# (d,ddd)
# (d,fff)
# (d,iii)
# (d,jjj)
# (a,aaa)
# (a,ccc)
# (a,ddd)
# (a,fff)
# (a,iii)
# (a,jjj)
# (b,ddd)
# (b,fff)
# (b,hhh)
# (a,ddd)
# (a,fff)
# (a,hhh)
# (d,ccc)
# (d,bbb)
# (d,eee)
# (d,ggg)
# (d,fff)
# (d,iii)
# (e,ccc)
# (e,bbb)
# (e,eee)
# (e,ggg)
# (e,fff)
# (e,iii)
# (a,ccc)
# (a,bbb)
# (a,eee)
# (a,ggg)
# (a,fff)
# (a,iii)
# (f,ccc)
# (f,bbb)
# (f,eee)
# (f,ggg)
# (f,fff)
# (f,iii)
# (d,bbb)
# (d,eee)
# (d,ggg)
# (d,fff)
# (d,iii)
# (d,jjj)
# (b,bbb)
# (b,eee)
# (b,ggg)
# (b,fff)
# (b,iii)
# (b,jjj)
# (g,bbb)
# (g,eee)
# (g,ggg)
# (g,fff)
# (g,iii)
# (g,jjj)
# (f,bbb)
# (f,eee)
# (f,ggg)
# (f,fff)
# (f,iii)
# (f,jjj)
# (d,eee)
# (d,fff)
# (d,iii)
# (d,hhh)
# (d,jjj)
# (c,eee)
# (c,fff)
# (c,iii)
# (c,hhh)
# (c,jjj)
# (f,eee)
# (f,fff)
# (f,iii)
# (f,hhh)
# (f,jjj)
# (b,eee)
# (b,fff)
# (b,iii)
# (b,hhh)
# (b,jjj)
# (d,bbb)
# (d,ggg)
# (d,iii)
# (e,bbb)
# (e,ggg)
# (e,iii)
# (a,bbb)
# (a,ggg)
# (a,iii)
# (c,bbb)
# (c,ggg)
# (c,iii)
# (g,aaa)
# (g,ccc)
# (g,bbb)
# (g,eee)
# (g,fff)
# (e,aaa)
# (e,ccc)
# (e,bbb)
# (e,eee)
# (e,fff)
# (f,aaa)
# (f,ccc)
# (f,bbb)
# (f,eee)
# (f,fff)
# (b,aaa)
# (b,ccc)
# (b,bbb)
# (b,eee)
# (b,fff)
# (c,aaa)
# (c,ddd)
# (c,jjj)
# (f,aaa)
# (f,ddd)
# (f,jjj)
# (d,aaa)
# (d,ccc)
# (d,ddd)
# (d,fff)
# (d,jjj)
# (b,aaa)
# (b,ccc)
# (b,ddd)
# (b,fff)
# (b,jjj)
# (f,ccc)
# (f,bbb)
# (f,eee)
# (f,ddd)
# (e,ccc)
# (e,bbb)
# (e,eee)
# (e,ddd)
# (e,bbb)
# (e,ddd)
# (e,ggg)
# (e,fff)
# (e,iii)
# (e,hhh)
# (b,bbb)
# (b,ddd)
# (b,ggg)
# (b,fff)
# (b,iii)
# (b,hhh)
# (f,bbb)
# (f,ddd)
# (f,ggg)
# (f,fff)
# (f,iii)
# (f,hhh)
# (g,ccc)
# (g,hhh)
# (g,jjj)
# (a,ccc)
# (a,hhh)
# (a,jjj)
# (e,ccc)
# (e,fff)
# (e,iii)
# (c,ccc)
# (c,fff)
# (c,iii)
# (f,ccc)
# (f,fff)
# (f,iii)
# (a,ccc)
# (a,fff)
# (a,iii)
# (e,aaa)
# (e,bbb)
# (e,fff)
# (a,aaa)
# (a,bbb)
# (a,fff)
# (e,aaa)
# (e,ddd)
# (e,iii)
# (f,aaa)
# (f,ddd)
# (f,iii)
# (c,ccc)
# (c,fff)
# (c,iii)
# (b,ccc)
# (b,fff)
# (b,iii)
# (g,ccc)
# (g,fff)
# (g,iii)
# (c,eee)
# (c,ddd)
# (c,jjj)
# (f,eee)
# (f,ddd)
# (f,jjj)
# (a,eee)
# (a,ddd)
# (a,jjj)
# (f,ccc)
# (f,bbb)
# (f,ddd)
# (f,ggg)
# (f,jjj)
# (a,ccc)
# (a,bbb)
# (a,ddd)
# (a,ggg)
# (a,jjj)
# (d,ccc)
# (d,bbb)
# (d,ddd)
# (d,ggg)
# (d,jjj)
# (c,aaa)
# (c,ccc)
# (c,ggg)
# (c,iii)
# (c,hhh)
# (c,jjj)
# (d,aaa)
# (d,ccc)
# (d,ggg)
# (d,iii)
# (d,hhh)
# (d,jjj)
# (e,ccc)
# (e,bbb)
# (e,eee)
# (e,ddd)
# (e,fff)
# (e,iii)
# (d,ccc)
# (d,bbb)
# (d,eee)
# (d,ddd)
# (d,fff)
# (d,iii)
# (c,ccc)
# (c,bbb)
# (c,eee)
# (c,ddd)
# (c,fff)
# (c,iii)
# (a,ccc)
# (a,ddd)
# (a,fff)
# (e,ccc)
# (e,ddd)
# (e,fff)
# (f,ccc)
# (f,ddd)
# (f,fff)
# (c,ccc)
# (c,ddd)
# (c,ggg)
# (c,hhh)
# (c,jjj)
# (a,ccc)
# (a,ddd)
# (a,ggg)
# (a,hhh)
# (a,jjj)
# (g,ccc)
# (g,ddd)
# (g,ggg)
# (g,hhh)
# (g,jjj)
# (f,ccc)
# (f,eee)
# (f,iii)
# (f,hhh)
# (f,jjj)
# (e,ccc)
# (e,eee)
# (e,iii)
# (e,hhh)
# (e,jjj)
# (f,aaa)
# (f,ccc)
# (f,eee)
# (f,ddd)
# (f,ggg)
# (f,fff)
# (c,aaa)
# (c,ccc)
# (c,eee)
# (c,ddd)
# (c,ggg)
# (c,fff)
# (a,aaa)
# (a,ccc)
# (a,eee)
# (a,ddd)
# (a,ggg)
# (a,fff)
# (g,aaa)
# (g,ccc)
# (g,eee)
# (g,ddd)
# (g,ggg)
# (g,fff)
# (b,aaa)
# (b,ccc)
# (b,bbb)
# (b,eee)
# (b,ddd)
# (f,aaa)
# (f,ccc)
# (f,bbb)
# (f,eee)
# (f,ddd)
# (b,aaa)
# (b,bbb)
# (b,ddd)
# (b,fff)
# (b,iii)
# (b,hhh)
# (f,aaa)
# (f,bbb)
# (f,ddd)
# (f,fff)
# (f,iii)
# (f,hhh)
# (a,ccc)
# (a,eee)
# (a,ggg)
# (a,fff)
# (c,ccc)
# (c,eee)
# (c,ggg)
# (c,fff)
# (b,ccc)
# (b,ddd)
# (b,ggg)
# (b,iii)
# (b,hhh)
# (b,jjj)
# (f,ccc)
# (f,ddd)
# (f,ggg)
# (f,iii)
# (f,hhh)
# (f,jjj)
# (c,ccc)
# (c,ddd)
# (c,ggg)
# (c,iii)
# (c,hhh)
# (c,jjj)
# (f,ccc)
# (f,bbb)
# (f,ddd)
# (f,hhh)
# (f,jjj)
# (a,ccc)
# (a,bbb)
# (a,ddd)
# (a,hhh)
# (a,jjj)
# (e,ccc)
# (e,bbb)
# (e,ddd)
# (e,hhh)
# (e,jjj)
# (a,aaa)
# (a,ddd)
# (a,fff)
# (f,aaa)
# (f,ddd)
# (f,fff)
# (c,ccc)
# (c,bbb)
# (c,ddd)
# (c,iii)
# (c,jjj)
# (a,ccc)
# (a,bbb)
# (a,ddd)
# (a,iii)
# (a,jjj)
# (c,eee)
# (c,fff)
# (c,hhh)
# (a,eee)
# (a,fff)
# (a,hhh)
# (e,eee)
# (e,fff)
# (e,hhh)
# (f,eee)
# (f,fff)
# (f,hhh)
# (e,eee)
# (e,fff)
# (e,iii)
# (d,eee)
# (d,fff)
# (d,iii)
# (f,ggg)
# (f,hhh)
# (f,jjj)
# (a,ggg)
# (a,hhh)
# (a,jjj)
# (d,ggg)
# (d,hhh)
# (d,jjj)

# %%
# %%pig
# -- agrupa los registros que tienen la misma palabra
# grouped = GROUP words BY (p,q);
# DUMP grouped;
# Out:
#  -- agrupa los registros que tienen la misma palabra
#  grouped = GROUP words BY (p,q);
#  DUMP grouped;
# 2020-03-04 05:38:45,817 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:45,971 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:38:45,989 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-04 05:38:46,000 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 05:38:46,025 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-03-04 05:38:46,043 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583298438667_0044
# 2020-03-04 05:38:46,046 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-04 05:38:46,070 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583298438667_0044
# 2020-03-04 05:38:46,074 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://379139e472df:8088/proxy/application_1583298438667_0044/
# 2020-03-04 05:39:11,550 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:39:11,555 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:39:11,614 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:39:11,617 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:39:11,645 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:39:11,648 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:39:11,675 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:39:11,678 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:39:11,701 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:39:11,704 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:39:11,728 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:39:11,731 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:39:11,764 [main] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# ((a,aaa),{(a,aaa,3),(a,aaa,3),(a,aaa,0),(a,aaa,5),(a,aaa,2)})
# ((a,bbb),{(a,bbb,4),(a,bbb,9),(a,bbb,3),(a,bbb,8),(a,bbb,1),(a,bbb,7),(a,bbb,0)})
# ((a,ccc),{(a,ccc,1),(a,ccc,4),(a,ccc,1),(a,ccc,0),(a,ccc,9),(a,ccc,5),(a,ccc,2),(a,ccc,7),(a,ccc,7),(a,ccc,0),(a,ccc,3),(a,ccc,6),(a,ccc,1)})
# ((a,ddd),{(a,ddd,2),(a,ddd,7),(a,ddd,0),(a,ddd,6),(a,ddd,9),(a,ddd,5),(a,ddd,5),(a,ddd,5),(a,ddd,9),(a,ddd,2),(a,ddd,2),(a,ddd,3),(a,ddd,7)})
# ((a,eee),{(a,eee,1),(a,eee,7),(a,eee,4),(a,eee,4),(a,eee,5),(a,eee,3),(a,eee,0)})
# ((a,fff),{(a,fff,8),(a,fff,2),(a,fff,9),(a,fff,1),(a,fff,5),(a,fff,4),(a,fff,0),(a,fff,7),(a,fff,3),(a,fff,3)})
# ((a,ggg),{(a,ggg,6),(a,ggg,9),(a,ggg,6),(a,ggg,0),(a,ggg,0),(a,ggg,2),(a,ggg,3),(a,ggg,5)})
# ((a,hhh),{(a,hhh,3),(a,hhh,9),(a,hhh,8),(a,hhh,6),(a,hhh,9),(a,hhh,4),(a,hhh,1),(a,hhh,6)})
# ((a,iii),{(a,iii,0),(a,iii,7),(a,iii,6),(a,iii,6),(a,iii,9),(a,iii,6),(a,iii,5)})
# ((a,jjj),{(a,jjj,5),(a,jjj,1),(a,jjj,7),(a,jjj,5),(a,jjj,2),(a,jjj,2),(a,jjj,1),(a,jjj,3),(a,jjj,0),(a,jjj,7)})
# ((b,aaa),{(b,aaa,6),(b,aaa,2),(b,aaa,3),(b,aaa,9)})
# ((b,bbb),{(b,bbb,3),(b,bbb,9),(b,bbb,0),(b,bbb,1),(b,bbb,7),(b,bbb,6),(b,bbb,7)})
# ((b,ccc),{(b,ccc,0),(b,ccc,1),(b,ccc,5),(b,ccc,6),(b,ccc,6)})
# ((b,ddd),{(b,ddd,3),(b,ddd,9),(b,ddd,0),(b,ddd,5),(b,ddd,0),(b,ddd,2),(b,ddd,2)})
# ((b,eee),{(b,eee,3),(b,eee,4),(b,eee,2),(b,eee,7),(b,eee,5)})
# ((b,fff),{(b,fff,9),(b,fff,8),(b,fff,5),(b,fff,2),(b,fff,4),(b,fff,4),(b,fff,3),(b,fff,7)})
# ((b,ggg),{(b,ggg,8),(b,ggg,9),(b,ggg,3),(b,ggg,2)})
# ((b,hhh),{(b,hhh,1),(b,hhh,5),(b,hhh,6),(b,hhh,5),(b,hhh,2),(b,hhh,9),(b,hhh,1)})
# ((b,iii),{(b,iii,7),(b,iii,5),(b,iii,7),(b,iii,4),(b,iii,4),(b,iii,0),(b,iii,3)})
# ((b,jjj),{(b,jjj,9),(b,jjj,6),(b,jjj,3),(b,jjj,8),(b,jjj,1)})
# ((c,aaa),{(c,aaa,8),(c,aaa,2),(c,aaa,7),(c,aaa,3),(c,aaa,1)})
# ((c,bbb),{(c,bbb,2),(c,bbb,7),(c,bbb,7),(c,bbb,4)})
# ((c,ccc),{(c,ccc,2),(c,ccc,1),(c,ccc,5),(c,ccc,6),(c,ccc,0),(c,ccc,7),(c,ccc,1),(c,ccc,0),(c,ccc,0),(c,ccc,4),(c,ccc,1),(c,ccc,1)})
# ((c,ddd),{(c,ddd,6),(c,ddd,5),(c,ddd,0),(c,ddd,0),(c,ddd,0),(c,ddd,5),(c,ddd,9),(c,ddd,7),(c,ddd,2)})
# ((c,eee),{(c,eee,4),(c,eee,5),(c,eee,3),(c,eee,0),(c,eee,1),(c,eee,6)})
# ((c,fff),{(c,fff,9),(c,fff,4),(c,fff,2),(c,fff,1),(c,fff,3),(c,fff,8),(c,fff,2),(c,fff,3)})
# ((c,ggg),{(c,ggg,6),(c,ggg,0),(c,ggg,9),(c,ggg,2),(c,ggg,3),(c,ggg,8),(c,ggg,5)})
# ((c,hhh),{(c,hhh,0),(c,hhh,6),(c,hhh,9),(c,hhh,3),(c,hhh,9),(c,hhh,5),(c,hhh,6)})
# ((c,iii),{(c,iii,7),(c,iii,6),(c,iii,7),(c,iii,6),(c,iii,0),(c,iii,7),(c,iii,7),(c,iii,4)})
# ((c,jjj),{(c,jjj,2),(c,jjj,8),(c,jjj,1),(c,jjj,1),(c,jjj,6),(c,jjj,2),(c,jjj,1),(c,jjj,7)})
# ((d,aaa),{(d,aaa,5),(d,aaa,7),(d,aaa,1),(d,aaa,2)})
# ((d,bbb),{(d,bbb,0),(d,bbb,7),(d,bbb,2),(d,bbb,7),(d,bbb,3),(d,bbb,7)})
# ((d,ccc),{(d,ccc,1),(d,ccc,4),(d,ccc,1),(d,ccc,0),(d,ccc,7),(d,ccc,5),(d,ccc,0)})
# ((d,ddd),{(d,ddd,0),(d,ddd,5),(d,ddd,9),(d,ddd,3),(d,ddd,2)})
# ((d,eee),{(d,eee,4),(d,eee,6),(d,eee,4),(d,eee,0),(d,eee,4),(d,eee,3)})
# ((d,fff),{(d,fff,2),(d,fff,1),(d,fff,8),(d,fff,5),(d,fff,7),(d,fff,3),(d,fff,7),(d,fff,9)})
# ((d,ggg),{(d,ggg,9),(d,ggg,0),(d,ggg,3),(d,ggg,8),(d,ggg,2),(d,ggg,6)})
# ((d,hhh),{(d,hhh,9),(d,hhh,0),(d,hhh,8),(d,hhh,6)})
# ((d,iii),{(d,iii,9),(d,iii,4),(d,iii,0),(d,iii,2),(d,iii,0),(d,iii,4),(d,iii,7),(d,iii,6),(d,iii,6)})
# ((d,jjj),{(d,jjj,5),(d,jjj,6),(d,jjj,1),(d,jjj,6),(d,jjj,1),(d,jjj,9),(d,jjj,7),(d,jjj,3)})
# ((e,aaa),{(e,aaa,4),(e,aaa,3),(e,aaa,3)})
# ((e,bbb),{(e,bbb,9),(e,bbb,8),(e,bbb,9),(e,bbb,6),(e,bbb,0),(e,bbb,7),(e,bbb,9),(e,bbb,7)})
# ((e,ccc),{(e,ccc,5),(e,ccc,6),(e,ccc,1),(e,ccc,4),(e,ccc,3),(e,ccc,1),(e,ccc,3),(e,ccc,6),(e,ccc,0)})
# ((e,ddd),{(e,ddd,3),(e,ddd,2),(e,ddd,5),(e,ddd,9),(e,ddd,2),(e,ddd,0),(e,ddd,7)})
# ((e,eee),{(e,eee,2),(e,eee,0),(e,eee,4),(e,eee,5),(e,eee,6),(e,eee,0),(e,eee,6)})
# ((e,fff),{(e,fff,4),(e,fff,2),(e,fff,7),(e,fff,4),(e,fff,0),(e,fff,3),(e,fff,9),(e,fff,9),(e,fff,1)})
# ((e,ggg),{(e,ggg,5),(e,ggg,9),(e,ggg,9),(e,ggg,6)})
# ((e,hhh),{(e,hhh,5),(e,hhh,6),(e,hhh,6),(e,hhh,6)})
# ((e,iii),{(e,iii,7),(e,iii,6),(e,iii,6),(e,iii,3),(e,iii,2),(e,iii,4),(e,iii,9),(e,iii,2)})
# ((e,jjj),{(e,jjj,0),(e,jjj,0),(e,jjj,1)})
# ((f,aaa),{(f,aaa,0),(f,aaa,4),(f,aaa,6),(f,aaa,8),(f,aaa,3),(f,aaa,9),(f,aaa,2),(f,aaa,3)})
# ((f,bbb),{(f,bbb,3),(f,bbb,8),(f,bbb,9),(f,bbb,6),(f,bbb,0),(f,bbb,7),(f,bbb,7),(f,bbb,9),(f,bbb,0),(f,bbb,3)})
# ((f,ccc),{(f,ccc,6),(f,ccc,0),(f,ccc,7),(f,ccc,6),(f,ccc,2),(f,ccc,1),(f,ccc,3),(f,ccc,1),(f,ccc,5),(f,ccc,4),(f,ccc,7),(f,ccc,3),(f,ccc,6)})
# ((f,ddd),{(f,ddd,9),(f,ddd,7),(f,ddd,0),(f,ddd,5),(f,ddd,2),(f,ddd,2),(f,ddd,5),(f,ddd,5),(f,ddd,6),(f,ddd,0),(f,ddd,3),(f,ddd,7),(f,ddd,0),(f,ddd,9),(f,ddd,9),(f,ddd,5),(f,ddd,3)})
# ((f,eee),{(f,eee,4),(f,eee,3),(f,eee,2),(f,eee,0),(f,eee,3),(f,eee,5),(f,eee,4),(f,eee,1),(f,eee,4),(f,eee,6),(f,eee,5)})
# ((f,fff),{(f,fff,4),(f,fff,9),(f,fff,2),(f,fff,5),(f,fff,7),(f,fff,0),(f,fff,4),(f,fff,9),(f,fff,5),(f,fff,2),(f,fff,4)})
# ((f,ggg),{(f,ggg,3),(f,ggg,6),(f,ggg,0),(f,ggg,5),(f,ggg,3),(f,ggg,2),(f,ggg,9),(f,ggg,0),(f,ggg,8)})
# ((f,hhh),{(f,hhh,5),(f,hhh,6),(f,hhh,1),(f,hhh,6),(f,hhh,6),(f,hhh,8),(f,hhh,9),(f,hhh,2),(f,hhh,5),(f,hhh,6)})
# ((f,iii),{(f,iii,2),(f,iii,7),(f,iii,4),(f,iii,9),(f,iii,0),(f,iii,6),(f,iii,7),(f,iii,4),(f,iii,3),(f,iii,6)})
# ((f,jjj),{(f,jjj,3),(f,jjj,1),(f,jjj,8),(f,jjj,1),(f,jjj,0),(f,jjj,0),(f,jjj,5),(f,jjj,1),(f,jjj,1),(f,jjj,9),(f,jjj,2),(f,jjj,3)})
# ((g,aaa),{(g,aaa,2),(g,aaa,3),(g,aaa,5)})
# ((g,bbb),{(g,bbb,7),(g,bbb,9),(g,bbb,0)})
# ((g,ccc),{(g,ccc,1),(g,ccc,7),(g,ccc,9),(g,ccc,0),(g,ccc,5),(g,ccc,6)})
# ((g,ddd),{(g,ddd,2),(g,ddd,9),(g,ddd,6),(g,ddd,9),(g,ddd,5)})
# ((g,eee),{(g,eee,1),(g,eee,4),(g,eee,3),(g,eee,2)})
# ((g,fff),{(g,fff,8),(g,fff,5),(g,fff,4),(g,fff,4),(g,fff,8)})
# ((g,ggg),{(g,ggg,0),(g,ggg,2),(g,ggg,8),(g,ggg,6)})
# ((g,hhh),{(g,hhh,4),(g,hhh,3),(g,hhh,2)})
# ((g,iii),{(g,iii,7),(g,iii,6),(g,iii,4),(g,iii,0)})
# ((g,jjj),{(g,jjj,3),(g,jjj,7),(g,jjj,7),(g,jjj,3),(g,jjj,9),(g,jjj,5)})

# %%
# %%pig
# -- genera una variable que cuenta las ocurrencias por cada grupo
# wordcount = FOREACH grouped GENERATE group, COUNT(words);
# DUMP wordcount;
# Out:
#  -- genera una variable que cuenta las ocurrencias por cada grupo
#  wordcount = FOREACH grouped GENERATE group, COUNT(words);
#  DUMP wordcount;
# 2020-03-04 05:39:12,066 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:39:12,179 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:39:12,201 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-04 05:39:12,212 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 05:39:12,242 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-03-04 05:39:12,693 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583298438667_0045
# 2020-03-04 05:39:12,695 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-04 05:39:12,723 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583298438667_0045
# 2020-03-04 05:39:12,726 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://379139e472df:8088/proxy/application_1583298438667_0045/
# 2020-03-04 05:39:32,844 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:39:32,850 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:39:32,910 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:39:32,915 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:39:32,941 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:39:32,943 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:39:32,969 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:39:32,972 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:39:32,996 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:39:32,999 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:39:33,023 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 05:39:33,025 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 05:39:33,052 [main] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# ((a,aaa),5)
# ((a,bbb),7)
# ((a,ccc),13)
# ((a,ddd),13)
# ((a,eee),7)
# ((a,fff),10)
# ((a,ggg),8)
# ((a,hhh),8)
# ((a,iii),7)
# ((a,jjj),10)
# ((b,aaa),4)
# ((b,bbb),7)
# ((b,ccc),5)
# ((b,ddd),7)
# ((b,eee),5)
# ((b,fff),8)
# ((b,ggg),4)
# ((b,hhh),7)
# ((b,iii),7)
# ((b,jjj),5)
# ((c,aaa),5)
# ((c,bbb),4)
# ((c,ccc),12)
# ((c,ddd),9)
# ((c,eee),6)
# ((c,fff),8)
# ((c,ggg),7)
# ((c,hhh),7)
# ((c,iii),8)
# ((c,jjj),8)
# ((d,aaa),4)
# ((d,bbb),6)
# ((d,ccc),7)
# ((d,ddd),5)
# ((d,eee),6)
# ((d,fff),8)
# ((d,ggg),6)
# ((d,hhh),4)
# ((d,iii),9)
# ((d,jjj),8)
# ((e,aaa),3)
# ((e,bbb),8)
# ((e,ccc),9)
# ((e,ddd),7)
# ((e,eee),7)
# ((e,fff),9)
# ((e,ggg),4)
# ((e,hhh),4)
# ((e,iii),8)
# ((e,jjj),3)
# ((f,aaa),8)
# ((f,bbb),10)
# ((f,ccc),13)
# ((f,ddd),17)
# ((f,eee),11)
# ((f,fff),11)
# ((f,ggg),9)
# ((f,hhh),10)
# ((f,iii),10)
# ((f,jjj),12)
# ((g,aaa),3)
# ((g,bbb),3)
# ((g,ccc),6)
# ((g,ddd),5)
# ((g,eee),4)
# ((g,fff),5)
# ((g,ggg),4)
# ((g,hhh),3)
# ((g,iii),4)
# ((g,jjj),6)

# %%
# %pig_quit

# %%
########################################################################################################
########################################################################################################
########################################################################################################
########################################################################################################
########################################################################################################
########################################################################################################
## Código en Apache Pig
##   Nota. Se usan los dos guiones -- para comentario de una línea y /* … */ para comentarios de varias líneas.
########################################################################################################
########################################################################################################
########################################################################################################
########################################################################################################
########################################################################################################
########################################################################################################

# %%
## Limpieza del HDFS y de la máquina local
## Se crea el directorio de entrada
## Se elimina el directorio de salida en el hdfs si existe
# !hadoop fs -rm input/*
# !hadoop fs -rm output/*
# !hadoop fs -rmdir output input
## Se elimina la carpeta si existe
# !rm -rf output input
# !mkdir output input
# Out:
# rm: `input/*': No such file or directory
# rm: `output/*': No such file or directory
# rmdir: `output': No such file or directory
# rmdir: `input': No such file or directory

# %%
# %%writefile script.pig
#
# -- carga de datos
# lines = LOAD 'data.tsv' AS (clave:CHARARRAY, reg1:BAG{t:(p:CHARARRAY)}, reg2:MAP[]);
#
# -- genera una tabla llamada words con una palabra por registro
# words = FOREACH lines GENERATE FLATTEN(reg1) AS (p:CHARARRAY), FLATTEN(reg2) AS (q:CHARARRAY, r:INT);
#
# -- agrupa los registros que tienen la misma palabra
# grouped = GROUP words BY (p,q);
#
# -- genera una variable que cuenta las ocurrencias por cada grupo
# wordcount = FOREACH grouped GENERATE group, COUNT(words);
#
# -- escribe el archivo de salida
# STORE wordcount INTO 'output' USING PigStorage('\t');
#
# -- copia los archivos del HDFS al sistema local
# fs -get output/ .
# Out:
# Overwriting script.pig

# %%
## Ejecución del script en modo batch
# !pig -execute 'run script.pig'
# Out:
# 2020-03-04 05:44:29,893 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2020-03-04 05:44:31,629 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.textoutputformat.separator is deprecated. Instead, use mapreduce.output.textoutputformat.separator
# 2020-03-04 05:44:31,636 [main] ERROR org.apache.pig.tools.grunt.Grunt - ERROR 6000: <line 15, column 0> Output Location Validation Failed for: 'hdfs://0.0.0.0:9000/user/root/output More info to follow:
# Output directory hdfs://0.0.0.0:9000/user/root/output already exists
# Details at logfile: /datalake/Talleres jumonsalve/evaluacion-final-juancamilo1203unal/02-pig-50/q08-10/pig_1583300669206.log

# %%
## Visualización de los resultados en el HDFS
# !hadoop fs -cat output/*
# Out:
# (a,aaa)	5
# (a,bbb)	7
# (a,ccc)	13
# (a,ddd)	13
# (a,eee)	7
# (a,fff)	10
# (a,ggg)	8
# (a,hhh)	8
# (a,iii)	7
# (a,jjj)	10
# (b,aaa)	4
# (b,bbb)	7
# (b,ccc)	5
# (b,ddd)	7
# (b,eee)	5
# (b,fff)	8
# (b,ggg)	4
# (b,hhh)	7
# (b,iii)	7
# (b,jjj)	5
# (c,aaa)	5
# (c,bbb)	4
# (c,ccc)	12
# (c,ddd)	9
# (c,eee)	6
# (c,fff)	8
# (c,ggg)	7
# (c,hhh)	7
# (c,iii)	8
# (c,jjj)	8
# (d,aaa)	4
# (d,bbb)	6
# (d,ccc)	7
# (d,ddd)	5
# (d,eee)	6
# (d,fff)	8
# (d,ggg)	6
# (d,hhh)	4
# (d,iii)	9
# (d,jjj)	8
# (e,aaa)	3
# (e,bbb)	8
# (e,ccc)	9
# (e,ddd)	7
# (e,eee)	7
# (e,fff)	9
# (e,ggg)	4
# (e,hhh)	4
# (e,iii)	8
# (e,jjj)	3
# (f,aaa)	8
# (f,bbb)	10
# (f,ccc)	13
# (f,ddd)	17
# (f,eee)	11
# (f,fff)	11
# (f,ggg)	9
# (f,hhh)	10
# (f,iii)	10
# (f,jjj)	12
# (g,aaa)	3
# (g,bbb)	3
# (g,ccc)	6
# (g,ddd)	5
# (g,eee)	4
# (g,fff)	5
# (g,ggg)	4
# (g,hhh)	3
# (g,iii)	4
# (g,jjj)	6

# %%
## Visualilzación de resultados en el sistema local
# !cat output/*
# Out:
# (a,aaa),5
# (a,bbb),7
# (a,ccc),13
# (a,ddd),13
# (a,eee),7
# (a,fff),10
# (a,ggg),8
# (a,hhh),8
# (a,iii),7
# (a,jjj),10
# (b,aaa),4
# (b,bbb),7
# (b,ccc),5
# (b,ddd),7
# (b,eee),5
# (b,fff),8
# (b,ggg),4
# (b,hhh),7
# (b,iii),7
# (b,jjj),5
# (c,aaa),5
# (c,bbb),4
# (c,ccc),12
# (c,ddd),9
# (c,eee),6
# (c,fff),8
# (c,ggg),7
# (c,hhh),7
# (c,iii),8
# (c,jjj),8
# (d,aaa),4
# (d,bbb),6
# (d,ccc),7
# (d,ddd),5
# (d,eee),6
# (d,fff),8
# (d,ggg),6
# (d,hhh),4
# (d,iii),9
# (d,jjj),8
# (e,aaa),3
# (e,bbb),8
# (e,ccc),9
# (e,ddd),7
# (e,eee),7
# (e,fff),9
# (e,ggg),4
# (e,hhh),4
# (e,iii),8
# (e,jjj),3
# (f,aaa),8
# (f,bbb),10
# (f,ccc),13
# (f,ddd),17
# (f,eee),11
# (f,fff),11
# (f,ggg),9
# (f,hhh),10
# (f,iii),10
# (f,jjj),12
# (g,aaa),3
# (g,bbb),3
# (g,ccc),6
# (g,ddd),5
# (g,eee),4
# (g,fff),5
# (g,ggg),4
# (g,hhh),3
# (g,iii),4
# (g,jjj),6
