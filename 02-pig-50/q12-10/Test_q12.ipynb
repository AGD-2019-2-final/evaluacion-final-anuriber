# %%
########################################################################################################
## Ejecución de Pig en Jupyter
##    A continuación se describe como ejecutar comandos de Pig en Jupyter usando la extensión de Jupyter bigdata.
# %load_ext bigdata
# %pig_start
# %timeout 300
## WordCount en Apache Pig
##   Se cargan los archivos en Apache Pig.
# !hadoop fs -put *.csv .
# !hadoop fs -ls
# Out:
# put: `data.csv': File exists
# Found 1 items
# -rw-r--r--   1 root supergroup        632 2020-03-03 23:14 data.csv

# %%
# %%pig
# --
# -- Carga el archivo desde el disco duro
# --
# dataTable = LOAD 'data.csv' USING PigStorage(',')
#     AS (num:INT,
#         nombre:CHARARRAY,
#         apellido:CHARARRAY,
#         eventType:CHARARRAY,
#         fecha:CHARARRAY,
#         color:CHARARRAY,
#         idnum:INT);
# Out:
#  --
#  -- Carga el archivo desde el disco duro
#  --
#  dataTable = LOAD 'data.csv' USING PigStorage(',')
#     AS (num:INT,
#         nombre:CHARARRAY,
#         apellido:CHARARRAY,
#         eventType:CHARARRAY,
#         fecha:CHARARRAY,
#         color:CHARARRAY,
#         idnum:INT);

# %%
# %%pig
# x = FOREACH dataTable GENERATE apellido, num;
# DUMP x;
# Out:
#  x = FOREACH dataTable GENERATE apellido, num;
#  DUMP x;
# 2020-03-04 00:47:08,854 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:47:09,332 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:47:09,344 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-04 00:47:09,352 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:47:09,374 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-03-04 00:47:09,389 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583277028520_0082
# 2020-03-04 00:47:09,391 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-04 00:47:09,413 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583277028520_0082
# 2020-03-04 00:47:09,416 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://2cc65e834313:8088/proxy/application_1583277028520_0082/
# 2020-03-04 00:47:24,578 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:47:24,581 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:47:24,627 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:47:24,629 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:47:24,654 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:47:24,656 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:47:24,673 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:47:24,675 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:47:24,694 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:47:24,696 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:47:24,712 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:47:24,714 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:47:24,744 [main] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# (Hamilton,1)
# (Holcomb,2)
# (Garrett,3)
# (Fry,4)
# (Conway,5)
# (Kinney,6)
# (Klein,7)
# (Diaz,8)
# (Guy,9)
# (Sexton,10)
# (Estes,11)
# (Coffey,12)
# (Crane,13)
# (Noel,14)
# (Silva,15)
# (Jarvis,16)
# (Boyer,17)
# (Knight,18)

# %%
# %%pig
# y1 = FILTER x BY (apellido matches '.*D.*');
# y2 = FILTER x BY (apellido matches '.*E.*');
# y3 = FILTER x BY (apellido matches '.*F.*');
# y4 = FILTER x BY (apellido matches '.*G.*');
# y5 = FILTER x BY (apellido matches '.*H.*');
# y6 = FILTER x BY (apellido matches '.*I.*');
# y7 = FILTER x BY (apellido matches '.*J.*');
# y8 = FILTER x BY (apellido matches '.*K.*');
#
# s = UNION y1, y2, y3, y4, y5, y6, y7, y8;
# DUMP s;
# Out:
#  y1 = FILTER x BY (apellido matches '.*D.*');
#  y2 = FILTER x BY (apellido matches '.*E.*');
#  y3 = FILTER x BY (apellido matches '.*F.*');
#  y4 = FILTER x BY (apellido matches '.*G.*');
#  y5 = FILTER x BY (apellido matches '.*H.*');
#  y6 = FILTER x BY (apellido matches '.*I.*');
#  y7 = FILTER x BY (apellido matches '.*J.*');
#  y8 = FILTER x BY (apellido matches '.*K.*');
#  s = UNION y1, y2, y3, y4, y5, y6, y7, y8;
#  DUMP s;
# 2020-03-04 00:48:27,504 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:48:27,607 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:48:27,619 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-04 00:48:27,624 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:48:27,627 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:48:27,637 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:48:27,640 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:48:27,642 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:48:27,645 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:48:27,649 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:48:27,652 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:48:27,687 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:8
# 2020-03-04 00:48:27,728 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583277028520_0084
# 2020-03-04 00:48:27,730 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-04 00:48:27,758 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583277028520_0084
# 2020-03-04 00:48:27,761 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://2cc65e834313:8088/proxy/application_1583277028520_0084/
# 2020-03-04 00:49:07,820 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:49:07,824 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:49:07,890 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:49:07,893 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:49:07,913 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:49:07,915 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:49:07,935 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:49:07,937 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:49:07,963 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:49:07,965 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:49:07,983 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:49:07,988 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:49:08,012 [main] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 8
# (Jarvis,16)
# (Hamilton,1)
# (Holcomb,2)
# (Estes,11)
# (Garrett,3)
# (Guy,9)
# (Kinney,6)
# (Klein,7)
# (Knight,18)
# (Fry,4)
# (Diaz,8)

# %%
# %%pig
# y = ORDER s BY $1;
# DUMP y;
# Out:
#  y = ORDER s BY $1;
#  DUMP y;
# 2020-03-04 00:49:48,443 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:49:48,946 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:49:48,955 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-04 00:49:48,962 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:49:48,965 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:49:48,967 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:49:48,969 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:49:48,974 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:49:48,979 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:49:48,982 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:49:48,988 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:49:49,435 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:8
# 2020-03-04 00:49:49,453 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583277028520_0085
# 2020-03-04 00:49:49,455 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-04 00:49:49,473 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583277028520_0085
# 2020-03-04 00:49:49,477 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://2cc65e834313:8088/proxy/application_1583277028520_0085/
# 2020-03-04 00:50:19,607 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:50:19,612 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:50:19,666 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:50:19,668 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:50:19,689 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:50:19,695 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:50:20,199 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:50:20,208 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-04 00:50:20,219 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 8
# 2020-03-04 00:50:20,642 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-03-04 00:50:20,661 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583277028520_0086
# 2020-03-04 00:50:20,663 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-04 00:50:20,683 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583277028520_0086
# 2020-03-04 00:50:20,685 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://2cc65e834313:8088/proxy/application_1583277028520_0086/
# 2020-03-04 00:50:40,865 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:50:40,873 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:50:40,931 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:50:40,934 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:50:40,953 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:50:40,964 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:50:41,062 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:50:41,078 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-04 00:50:41,087 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 8
# 2020-03-04 00:50:41,515 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-03-04 00:50:41,935 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583277028520_0087
# 2020-03-04 00:50:41,937 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-04 00:50:41,960 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583277028520_0087
# 2020-03-04 00:50:41,963 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://2cc65e834313:8088/proxy/application_1583277028520_0087/
# 2020-03-04 00:51:07,322 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:51:07,326 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:51:07,368 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:51:07,370 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:51:07,391 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:51:07,392 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:51:07,429 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:51:07,431 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:51:07,464 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:51:07,466 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:51:07,484 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:51:07,486 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:51:07,505 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:51:07,507 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:51:07,537 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:51:07,539 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:51:07,556 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:51:07,558 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:51:07,577 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:51:07,579 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:51:07,596 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:51:07,598 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:51:07,616 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:51:07,618 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:51:07,640 [main] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# (Hamilton,1)
# (Holcomb,2)
# (Garrett,3)
# (Fry,4)
# (Kinney,6)
# (Klein,7)
# (Diaz,8)
# (Guy,9)
# (Estes,11)
# (Jarvis,16)
# (Knight,18)

# %%
# %%pig
# z = FOREACH y GENERATE $0;
# DUMP z;
# Out:
#  z = FOREACH y GENERATE $0;
#  DUMP z;
# 2020-03-04 00:56:58,943 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:56:59,433 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:56:59,447 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-04 00:56:59,453 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:56:59,455 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:56:59,458 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:56:59,460 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:56:59,462 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:56:59,464 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:56:59,466 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:56:59,469 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 00:56:59,488 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:8
# 2020-03-04 00:56:59,902 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583277028520_0088
# 2020-03-04 00:56:59,904 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-04 00:56:59,926 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583277028520_0088
# 2020-03-04 00:56:59,929 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://2cc65e834313:8088/proxy/application_1583277028520_0088/
# 2020-03-04 00:57:30,045 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:57:30,050 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:57:30,110 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:57:30,112 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:57:30,130 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:57:30,132 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:57:31,844 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:57:31,853 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-04 00:57:31,861 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 8
# 2020-03-04 00:57:31,879 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-03-04 00:57:32,295 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583277028520_0089
# 2020-03-04 00:57:32,298 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-04 00:57:32,336 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583277028520_0089
# 2020-03-04 00:57:32,338 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://2cc65e834313:8088/proxy/application_1583277028520_0089/
# 2020-03-04 00:57:52,742 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:57:52,767 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:57:52,869 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:57:52,874 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:57:52,906 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:57:52,908 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:57:53,535 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:57:53,550 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-04 00:57:53,562 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 8
# 2020-03-04 00:57:53,604 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-03-04 00:57:54,025 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583277028520_0091
# 2020-03-04 00:57:54,029 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-04 00:57:54,048 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583277028520_0091
# 2020-03-04 00:57:54,052 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://2cc65e834313:8088/proxy/application_1583277028520_0091/
# 2020-03-04 00:58:34,120 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:58:34,125 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:58:34,206 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:58:34,208 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:58:34,235 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:58:34,237 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:58:34,263 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:58:34,264 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:58:34,287 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:58:34,290 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:58:34,307 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:58:34,309 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:58:34,328 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:58:34,330 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:58:34,359 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:58:34,361 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:58:34,378 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:58:34,380 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:58:34,399 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:58:34,400 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:58:34,416 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:58:34,418 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:58:34,435 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 00:58:34,437 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 00:58:34,461 [main] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# (Hamilton)
# (Holcomb)
# (Garrett)
# (Fry)
# (Kinney)
# (Klein)
# (Diaz)
# (Guy)
# (Estes)
# (Jarvis)
# (Knight)

# %%
# %pig_quit

# %%
########################################################################################################
########################################################################################################
########################################################################################################
########################################################################################################
########################################################################################################
########################################################################################################
## Código en Apache Pig
##   Nota. Se usan los dos guiones -- para comentario de una línea y /* … */ para comentarios de varias líneas.
########################################################################################################
########################################################################################################
########################################################################################################
########################################################################################################
########################################################################################################
########################################################################################################

# %%
## Limpieza del HDFS y de la máquina local
## Se crea el directorio de entrada
## Se elimina el directorio de salida en el hdfs si existe
# !hadoop fs -rm input/*
# !hadoop fs -rm output/*
# !hadoop fs -rmdir output input
## Se elimina la carpeta si existe
# !rm -rf output input
# !mkdir output input
# Out:
# rm: `input/*': No such file or directory
# Deleted output/_SUCCESS
# Deleted output/part-m-00000
# rmdir: `input': No such file or directory

# %%
# %%writefile script.pig
#
# -- Carga el archivo desde el disco duro
# --
# dataTable = LOAD 'data.csv' USING PigStorage(',')
#     AS (num:INT,
#         nombre:CHARARRAY,
#         apellido:CHARARRAY,
#         eventType:CHARARRAY,
#         fecha:CHARARRAY,
#         color:CHARARRAY,
#         idnum:INT);
#
# x = FOREACH dataTable GENERATE apellido, num;
#
# y1 = FILTER x BY (apellido matches '.*D.*');
# y2 = FILTER x BY (apellido matches '.*E.*');
# y3 = FILTER x BY (apellido matches '.*F.*');
# y4 = FILTER x BY (apellido matches '.*G.*');
# y5 = FILTER x BY (apellido matches '.*H.*');
# y6 = FILTER x BY (apellido matches '.*I.*');
# y7 = FILTER x BY (apellido matches '.*J.*');
# y8 = FILTER x BY (apellido matches '.*K.*');
# s = UNION y1, y2, y3, y4, y5, y6, y7, y8;
#
# y = ORDER s BY $1;
# z = FOREACH y GENERATE $0;
#
# -- escribe el archivo de salida
# STORE z INTO 'output' USING PigStorage(',');
#
# -- copia los archivos del HDFS al sistema local
# fs -get output/ .
# Out:
# Writing script.pig

# %%
## Ejecución del script en modo batch
# !pig -execute 'run script.pig'
# Out:
# 2020-03-04 01:00:08,001 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2020-03-04 01:00:09,577 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.textoutputformat.separator is deprecated. Instead, use mapreduce.output.textoutputformat.separator
# 2020-03-04 01:00:10,020 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 01:00:10,219 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# 2020-03-04 01:00:10,223 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.output.compress is deprecated. Instead, use mapreduce.output.fileoutputformat.compress
# 2020-03-04 01:00:10,238 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.submit.replication is deprecated. Instead, use mapreduce.client.submit.file.replication
# 2020-03-04 01:00:10,606 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker.http.address is deprecated. Instead, use mapreduce.jobtracker.http.address
# 2020-03-04 01:00:10,615 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 01:00:10,637 [JobControl] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2020-03-04 01:00:10,756 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-04 01:00:10,799 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 01:00:10,825 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 01:00:10,837 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 01:00:10,845 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 01:00:10,853 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 01:00:10,861 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 01:00:10,867 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 01:00:10,874 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-03-04 01:00:10,923 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:8
# 2020-03-04 01:00:11,057 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583277028520_0092
# 2020-03-04 01:00:11,239 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-04 01:00:11,305 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583277028520_0092
# 2020-03-04 01:00:11,342 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://2cc65e834313:8088/proxy/application_1583277028520_0092/
# 2020-03-04 01:00:41,491 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 01:00:41,500 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 01:00:41,659 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 01:00:41,664 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 01:00:41,692 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 2020-03-04 01:00:41,694 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 01:00:41,697 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 01:00:41,930 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 01:00:41,975 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-04 01:00:41,997 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 8
# 2020-03-04 01:00:42,026 [DataStreamer for file /tmp/hadoop-yarn/staging/root/.staging/job_1583277028520_0093/job.split] WARN  org.apache.hadoop.hdfs.DataStreamer - Caught exception
# java.lang.InterruptedException
# 	at java.lang.Object.wait(Native Method)
# 	at java.lang.Thread.join(Thread.java:1252)
# 	at java.lang.Thread.join(Thread.java:1326)
# 	at org.apache.hadoop.hdfs.DataStreamer.closeResponder(DataStreamer.java:973)
# 	at org.apache.hadoop.hdfs.DataStreamer.endBlock(DataStreamer.java:624)
# 	at org.apache.hadoop.hdfs.DataStreamer.run(DataStreamer.java:801)
# 2020-03-04 01:00:42,051 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-03-04 01:00:42,117 [DataStreamer for file /tmp/hadoop-yarn/staging/root/.staging/job_1583277028520_0093/job.xml] WARN  org.apache.hadoop.hdfs.DataStreamer - Caught exception
# java.lang.InterruptedException
# 	at java.lang.Object.wait(Native Method)
# 	at java.lang.Thread.join(Thread.java:1252)
# 	at java.lang.Thread.join(Thread.java:1326)
# 	at org.apache.hadoop.hdfs.DataStreamer.closeResponder(DataStreamer.java:973)
# 	at org.apache.hadoop.hdfs.DataStreamer.endBlock(DataStreamer.java:624)
# 	at org.apache.hadoop.hdfs.DataStreamer.run(DataStreamer.java:801)
# 2020-03-04 01:00:42,118 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583277028520_0093
# 2020-03-04 01:00:42,124 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-04 01:00:42,166 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583277028520_0093
# 2020-03-04 01:00:42,171 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://2cc65e834313:8088/proxy/application_1583277028520_0093/
# 2020-03-04 01:01:07,425 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 01:01:07,433 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 01:01:07,527 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 01:01:07,534 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 01:01:07,571 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 01:01:07,574 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 01:01:07,759 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 01:01:07,786 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-03-04 01:01:07,819 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 8
# 2020-03-04 01:01:07,852 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-03-04 01:01:07,877 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1583277028520_0095
# 2020-03-04 01:01:07,880 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-03-04 01:01:07,919 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1583277028520_0095
# 2020-03-04 01:01:07,923 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://2cc65e834313:8088/proxy/application_1583277028520_0095/
# 2020-03-04 01:01:48,111 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 01:01:48,120 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 01:01:48,170 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 01:01:48,174 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 01:01:48,207 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 01:01:48,210 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 01:01:48,253 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 01:01:48,258 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 01:01:48,303 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 01:01:48,307 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 01:01:48,336 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 01:01:48,342 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 01:01:48,382 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 01:01:48,386 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 01:01:48,418 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 01:01:48,421 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 01:01:48,453 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 01:01:48,455 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 01:01:48,488 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 01:01:48,491 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 01:01:48,521 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 01:01:48,525 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-03-04 01:01:48,558 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-03-04 01:01:48,561 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server

# %%
## Visualización de los resultados en el HDFS
# !hadoop fs -cat output/*
# Out:
# Hamilton
# Holcomb
# Garrett
# Fry
# Kinney
# Klein
# Diaz
# Guy
# Estes
# Jarvis
# Knight

# %%
## Visualilzación de resultados en el sistema local
# !cat output/*
# Out:
# Hamilton
# Holcomb
# Garrett
# Fry
# Kinney
# Klein
# Diaz
# Guy
# Estes
# Jarvis
# Knight

# %%
## Limpieza del HDFS y de la máquina local
## Se crea el directorio de entrada
## Se elimina el directorio de salida en el hdfs si existe
# !hadoop fs -rm input/*
# !hadoop fs -rm output/*
# !hadoop fs -rmdir output input
## Se elimina la carpeta si existe
# !rm -rf output input
# !mkdir output input
# Out:
# rm: `input/*': No such file or directory
# Deleted output/_SUCCESS
# Deleted output/part-r-00000
# rmdir: `input': No such file or directory
